# %%
# Import libraries

import pandas as pd
import seaborn as sns
import numpy as np

import matplotlib
import matplotlib.pyplot as plt

# %%
# Read the data

movies = pd.read_csv("data_set/movies.csv")

# %%
# View top 5 data and structure

movies.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# ...

# %%
# Check for missing data

movies.isnull().sum()
# Out:
# name           0
# rating        77
# genre          0
# year           0
# released       2
# score          3
# votes          3
# director       0
# writer         3
# star           1
# country        3
# budget      2171
# gross        189
# company       17
# runtime        4
# dtype: int64

# %%
# Drop null values

movies = movies.dropna()

# %%
# Check again for null values

movies.isnull().sum()
# Out:
# name        0
# rating      0
# genre       0
# year        0
# released    0
# score       0
# votes       0
# director    0
# writer      0
# star        0
# country     0
# budget      0
# gross       0
# company     0
# runtime     0
# dtype: int64

# %%
# Check datatypes of columns

movies.dtypes
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes       float64
# director     object
# writer       object
# star         object
# country      object
# budget      float64
# gross       float64
# company      object
# runtime     float64
# dtype: object

# %%
# Change budget and gross into int64, due to not needing ".00"

movies['budget'] = movies['budget'].astype('int64')
movies['gross'] = movies['gross'].astype('int64')

# %%
# Check types again

movies.dtypes
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes       float64
# director     object
# writer       object
# star         object
# country      object
# budget        int64
# gross         int64
# company      object
# runtime     float64
# dtype: object

# %%
# Look at table

movies.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country    budget  \
# ...

# %%
# Check which movies had the most votes

movies.sort_values(by=['votes'], inplace=False, ascending=False)
# Out:
#                           name rating   genre  year  \
# 5243           The Dark Knight  PG-13  Action  2008
# 2443  The Shawshank Redemption      R   Drama  1994
# 5643                 Inception  PG-13  Action  2010
# 2445              Forrest Gump  PG-13   Drama  1994
# 3444                Fight Club      R   Drama  1999
# ...                        ...    ...     ...   ...
# 1018               Sky Bandits     PG  Action  1986
# 802                Fever Pitch      R   Drama  1985
# 639                 Almost You      R  Comedy  1984
# 449              Getting It on      R  Comedy  1983
# 7616           High on the Hog      R  Action  2019
#
#                                released  score      votes           director  \
# 5243      July 18, 2008 (United States)    9.0  2400000.0  Christopher Nolan
# 2443   October 14, 1994 (United States)    9.3  2400000.0     Frank Darabont
# 5643      July 16, 2010 (United States)    8.8  2100000.0  Christopher Nolan
# ...

# %%
# Check which movies had the highest budget

movies.sort_values(by=['budget'], inplace=False, ascending=False)
# Out:
#                                           name   rating   genre  year  \
# 7445                         Avengers: Endgame    PG-13  Action  2019
# 7244                    Avengers: Infinity War    PG-13  Action  2018
# 7075   Star Wars: Episode VIII - The Last Jedi    PG-13  Action  2017
# 7066                            Justice League    PG-13  Action  2017
# 5060  Pirates of the Caribbean: at World's End    PG-13  Action  2007
# ...                                        ...      ...     ...   ...
# 2211                            The Living End  Unrated  Comedy  1992
# 5114                       Paranormal Activity        R  Horror  2007
# 2093                               El Mariachi        R  Action  1992
# 4507                                    Primer    PG-13   Drama  2004
# 3318                                 Following        R   Crime  1998
#
#                                released  score     votes           director  \
# ...

# %%
# Check which movies had the highest gross

movies.sort_values(by=['gross'], inplace=False, ascending=False)
# Out:
#                                             name     rating   genre  year  \
# 5445                                      Avatar      PG-13  Action  2009
# 7445                           Avengers: Endgame      PG-13  Action  2019
# 3045                                     Titanic      PG-13   Drama  1997
# 6663  Star Wars: Episode VII - The Force Awakens      PG-13  Action  2015
# 7244                      Avengers: Infinity War      PG-13  Action  2018
# ...                                          ...        ...     ...   ...
# 5640                                 Tanner Hall          R   Drama  2009
# 2434                  Philadelphia Experiment II      PG-13  Action  1993
# 3681                                Ginger Snaps  Not Rated   Drama  2000
# 272                                     Parasite          R  Horror  1982
# 3203                                  Trojan War      PG-13  Comedy  1997
#
#                                released  score      votes  \
# ...

# %%
# View all the companies distinct

movies['company'].drop_duplicates().sort_values(ascending=False)
# Out:
# 7129                                thefyzz
# 5664                            micro_scope
# 4007                               i5 Films
# 6793                             i am OTHER
# 6420                                   erbp
#                        ...
# 385                        1818 Productions
# 2929                          1492 Pictures
# 3024                        .406 Production
# 7525    "Weathering With You" Film Partners
# 4345        "DIA" Productions GmbH & Co. KG
# Name: company, Length: 1475, dtype: object

# %%
# Need to see the whole list, set max row none for whole access and run previous code again

pd.set_option('display.max_rows', None)

movies['company'].drop_duplicates().sort_values(ascending=False)
# Out:
# 7129                                              thefyzz
# 5664                                          micro_scope
# 4007                                             i5 Films
# 6793                                           i am OTHER
# 6420                                                 erbp
# 3776                                       double A Films
# 3330                          Zucker Brothers Productions
# 146                                      Zoetrope Studios
# 2213                                   Zeta Entertainment
# 3698                              Zentropa Entertainments
# 1180                                 Zenith Entertainment
# 5180                                      Zazen Produções
# 1321                             Zanuck/Brown Productions
# 1329                          Zacharias-Buhai Productions
# 789                             Young Sung Production Co.
# 5125                           Young Hannibal Productions
# ...

# %%
# Check correlation of votes and gross earnings

# Scatter plot 1
# Votes vs Gross

plt.scatter(x=movies['votes'],y=movies['gross'])
plt.title('Votes vs Gross Earnings')

plt.xlabel('Votes')
plt.ylabel('Gross')
plt.show()

# %%
# Plot using seaborn
# Scatter plot 1: Votes vs Gross Earnings

sns.regplot(x='votes',y='gross',data=movies, scatter_kws={"color": 'red'}, line_kws={"color":"blue"})
# Out:
# <Axes: xlabel='votes', ylabel='gross'>

# %%
# Scatter plot 2: Gross Earnings vs Budget

sns.regplot(x='budget',y='gross',data=movies, scatter_kws={"color": 'green'}, line_kws={"color":"blue"})
# Out:
# <Axes: xlabel='budget', ylabel='gross'>

# %%
# Scatter plot 3: Gross Earnings vs Score

sns.regplot(x='score',y='gross',data=movies, scatter_kws={"color": 'pink'}, line_kws={"color":"blue"})
# Out:
# <Axes: xlabel='score', ylabel='gross'>

# %%
# Check correlations

movies.corr()

# correlations that are strong are (gross & budget) and (gross & votes)
# Out:
# C:\Users\voden\AppData\Local\Temp\ipykernel_21708\2799931108.py:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   movies.corr()
#              year     score     votes    budget     gross   runtime
# year     1.000000  0.056386  0.206021  0.327722  0.274321  0.075077
# score    0.056386  1.000000  0.474256  0.072001  0.222556  0.414068
# votes    0.206021  0.474256  1.000000  0.439675  0.614751  0.352303
# budget   0.327722  0.072001  0.439675  1.000000  0.740247  0.318695
# gross    0.274321  0.222556  0.614751  0.740247  1.000000  0.275796
# runtime  0.075077  0.414068  0.352303  0.318695  0.275796  1.000000

# %%
# Assign correlation matrix

correlation_matrix = movies.corr()
# Out:
# C:\Users\voden\AppData\Local\Temp\ipykernel_21708\2560902226.py:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = movies.corr()

# %%
# Create a heatmap to visualize correlations

sns.heatmap(correlation_matrix, annot=True)
plt.title('Correlation Matrix Movies')
plt.show()
